# %% [markdown]
# Lists

# %%
l1 = [1,2,4,4,6,8,2,4]
print(l1)
# Out:
# [1, 2, 4, 4, 6, 8, 2, 4]

# %%
l1.index(4)
# Out:
# 2

# %%
l1.index(4,4) #frst 4 is value to search index for.. second 4 is from which index it shld strt searching
# Out:
# 7

# %%
l= [1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
print(len(l))
# Out:
# 4

# %%
print(l[0])
# Out:
# 1

# %%
l1 = [1,2,3,4,5,6]
l1.append(8)

# %%
l1.pop(4)
print(l1)
# Out:
# [1, 2, 3, 4, 6, 8]

# %%
l1.append([9,8,7])
print(l1)
# Out:
# [1, 2, 3, 4, 6, 8, [9, 8, 7], [9, 8, 7], [9, 8, 7]]

# %%
l1.pop()
print(l1)
# Out:
# [1, 2, 3, 4, 6, 8]

# %%
num = [9,1,2,4,5]
print(num)
# Out:
# [9, 1, 2, 4, 5]

# %%
num.insert(0,1)
print(num)
# Out:
# [1, 9, 1, 2, 4, 5]

# %%
num.remove(1)
print(num)
# Out:
# [9, 1, 2, 4, 5]

# %%
num.pop(1)
print(num)
# Out:
# [9, 2, 4, 5]

# %%
num.clear()
print(num)
# Out:
# []

# %%
print(9 in num)
# Out:
# False

# %%
fruits = ["apple", "ban", "guv", "orn", "grap"]

print(fruits)
# Out:
# ['apple', 'ban', 'guv', 'orn', 'grap']

# %%
print("apple" in fruits)
# Out:
# True

# %%
print(fruits[::-1])
# Out:
# ['grap', 'orn', 'guv', 'ban', 'apple']

# %%
print(fruits[-1:0:-1])
# Out:
# ['grap', 'orn', 'guv', 'ban']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'ban', 'grap', 'guv', 'orn']

# %%
fruits.reverse()
print(fruits)
# Out:
# ['orn', 'guv', 'grap', 'ban', 'apple']

# %%
print(fruits)
# Out:
# ['orn', 'guv', 'grap', 'ban', 'apple']

# %%
print(l)
# Out:
# [1, 2, 3]

# %%
l.reverse()
print(l)
# Out:
# [3, 2, 1]

# %%
l2 = l.copy()
print(l2)
# Out:
# [3, 2, 1]

# %%
l3 = [1,2,2,3,4,5,3,2,1,4]
print(l3)
# Out:
# [1, 2, 2, 3, 4, 5, 3, 2, 1, 4]

# %%
print(l3.count(2))
# Out:
# 3

# %%
print(l3[0:4])
# Out:
# [1, 2, 2, 3]

# %%
rev = l3[::-1]
print(rev)
# Out:
# [4, 1, 2, 3, 5, 4, 3, 2, 2, 1]

# %%
list= [1,2,3,4,5,6,7,8,9]
print(list[::2])
# Out:
# [1, 3, 5, 7, 9]

# %%
l=[1,3,5,3,4]
sortt=l.sort()
print(l)
# Out:
# [1, 3, 3, 4, 5]

# %%
l=[1,3,5,3,4]
sortt=sorted(l)
print(sortt)
# Out:
# [1, 3, 3, 4, 5]

# %%
l=[[1,2],[3,4]]

print(l[0])
print(l[1][1])
# Out:
# [1, 2]
# 4
