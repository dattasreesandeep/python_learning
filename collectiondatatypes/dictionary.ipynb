# %% [markdown]
# **Dictionary**

# %%
d={'name':'sandeep',
   'age':'21',
   'gender':'M',
   'name':'naruto',
   'age':'25'
   }
print(d)        #keys shold be unique values can be same
# Out:
# {'name': 'naruto', 'age': '25', 'gender': 'M'}

# %% [markdown]
# .get()

# %%
d.get('name','age')
# Out:
# 'naruto'

# %% [markdown]
# .values()

# %%
d.values()
# Out:
# dict_values(['naruto', '25'])

# %% [markdown]
# .keys()

# %%
print(d.keys())
# Out:
# dict_keys(['name', 'age'])

# %% [markdown]
# .items()

# %%
d.items()
# Out:
# dict_items([('name', 'naruto'), ('age', '25')])

# %% [markdown]
# .update()       here used to add

# %%
d.update({'height':'180'})
d.items()
# Out:
# dict_items([('name', 'naruto'), ('age', '25'), ('gender', 'M'), ('height', '180')])

# %% [markdown]
# .update()      here used to update

# %%
d.update({'height':'170'})
d.items()
# Out:
# dict_items([('name', 'naruto'), ('gender', 'M'), ('height', '170')])

# %% [markdown]
# .pop()

# %%
d.pop('age')
d.items()
# Out:
# dict_items([('name', 'naruto'), ('gender', 'M'), ('height', '170')])

# %% [markdown]
# .popitem()           last inserted item gets removed

# %%
d.popitem()
d.items()
# Out:
# dict_items([('name', 'naruto'), ('gender', 'M')])

# %% [markdown]
# .copy()

# %%
new_d=d.copy()

# %%
new_d.items()
# Out:
# dict_items([('name', 'naruto'), ('gender', 'M')])

# %% [markdown]
# .clear()

# %%
new_d.clear()

# %%
new_d.items()
# Out:
# dict_items([])

# %%
print(new_d)
# Out:
# {}

# %% [markdown]
# .setdefault()

# %%
d.setdefault('name','sasuke')
# Out:
# 'naruto'

# %% [markdown]
# overwriting

# %%
d['name']='sandeep'

# %%
d.setdefault('city','hyderabad')
# Out:
# 'hyderabad'

# %%
print(d)
# Out:
# {'name': 'sandeep', 'gender': 'M', 'city': 'hyderabad'}

# %% [markdown]
# additional importnt syntaxes

# %%
d['name']
# Out:
# 'sandeep'

# %%
d['name']='sandeep1'

# %%
d['name']
# Out:
# 'sandeep1'

# %%
d['sport']='bb'

# %%
del d['sport']
