# %% [markdown]
# Tuple

# %%
print(tuple[1])
# Out:
# 2

# %%
print(tuple[::2])
# Out:
# (1, 3, 5)

# %%
print(3 in tuple)
# Out:
# True

# %%
print(tuple.count(3))
print(tuple.index(3))
# Out:
# 1
# 2

# %%
t = (1,2,3,4,5)
l = list(t)
print(l)
print(type(l))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
n = (1,2,3,4,2,5,6,5,2,1)

new_n = (set(n))

print(new_n)
# Out:
# {1, 2, 3, 4, 5, 6}
