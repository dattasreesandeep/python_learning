# %% [markdown]
# Set

# %%
s={1,2,3,4,5}

# %%
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s.add(6)
print(s)
# Out:
# {1, 2, 3, 4, 6}

# %%
s.update([7,8,9])
print(s)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
s.remove(6)
print(s)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
s.discard(6)
print(s)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
s.pop()
print(s)
# Out:
# {2, 3, 4, 7, 8, 9}

# %%
n = {2,3,4,5,1,0}
n.pop()
print(n)
# Out:
# {1, 2, 3, 4, 5}

# %%
m = {"a","b","c","d"}
m.pop()
print(m)
# Out:
# {'d', 'a', 'b'}

# %%
m.clear()
print(m)
# Out:
# set()

# %%
m ={"apple","banana","cherry"}
print("apple" in m)
# Out:
# True

# %%
s = {1,2,3,2,1,4,5,5,4}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
new_n = list(s)
print(new_n)
type(new_n)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
se={1,2,3,4,5}
for i in se:
    if i % 2 == 0:
        print(i)
# Out:
# 2
# 4

# %%
for i in se:
    if i % 2 != 0:
        print(i)
# Out:
# 1
# 3
# 5

# %%
print(max(se))
print(min(se))
# Out:
# 5
# 1

# %%
print(sum(se))
# Out:
# 15

# %%
print(len(se))
# Out:
# 5

# %%
s = input("enter a number:")
print(s)
# Out:
# 1 2 3 4 5

# %%
a = {1,2,3,}
b = {3,4,5}
print(a |b)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(a & b)
# Out:
# {3}
