# %% [markdown]
# # =========================
# # PYTHON DATA STRUCTURES
# # FAST REVISION TABLE
# # =========================
#
# # -------------------------------------------------
# # GENERAL COMPARISON
# # -------------------------------------------------
#
# # Structure    Mutable   Ordered   Duplicates   Indexing
# # -------------------------------------------------------
# # List         Yes       Yes       Yes          Yes
# # Tuple        No        Yes       Yes          Yes
# # Set          Yes       No        No           No
# # Dictionary   Yes       Yes       Keys No      By key
#
#
# # -------------------------------------------------
# # CREATION
# # -------------------------------------------------
#
# # List
# l=[]
#
# # Tuple
# t=()
#
# # Set
# s=set()
#
# # Dictionary
# d={}
#
#
# # -------------------------------------------------
# # ADDING ELEMENTS
# # -------------------------------------------------
#
# # LIST
#
# l.append(10)          # add single element
# l.extend([20,30])    # add multiple elements multiple iterables cannot be added
# l.insert(1,100)      # insert at index at index 1 insert 100
#
#
# # SET
#
# s.add(10)             # add single element
# s.update([20,30])     # add multiple elements and multiple iterables
#
#
# # DICTIONARY
#
# d['name']='Sandeep'   # add key-value pair
# d.update({'age':21})  # add multiple pairs
#
#
# # -------------------------------------------------
# # REMOVING ELEMENTS
# # -------------------------------------------------
#
# # LIST
#
# l.remove(10)          # remove by value
# l.pop()               # remove last
# l.pop(1)              # remove by index
# l.clear()             # remove all
#
#
# # SET
#
# s.remove(10)          # remove element
# s.discard(10)         # safe remove error doestnot occur when 10 is not in set
# s.pop()               # remove random element
# s.clear()             # remove all
#
#
# # DICTIONARY
#
# d.pop('name')         # remove by key
# d.popitem()           # remove last pair
# d.clear()             # remove all
#
#
# # -------------------------------------------------
# # SEARCH OPERATIONS
# # -------------------------------------------------
#
# # LIST
#
# 10 in l
# 10 not in l
#
# l.index(10)
# l.count(10)
#
#
# # TUPLE
#
# 10 in t
# 10 not in t
#
# t.index(10)
# t.count(10)
#
#
# # SET
#
# 10 in s
# 10 not in s
#
# # Fastest searching
#
#
# # DICTIONARY
#
# 'name' in d          # searches keys
#
# 10 in d.values()     # searches values
#
# ('name',10) in d.items()   # searches key-value pair
#
# # -------------------------------------------------
# # SORTING / REVERSING
# # -------------------------------------------------
#
# # LIST
#
# l.sort()              # ascending
# l.sort(reverse=True)  # descending
# l.reverse()           # reverse list
#
# sorted(l)             # returns new sorted list
#
#
# # -------------------------------------------------
# # COPYING
# # -------------------------------------------------
#
# l2=l.copy()
# s2=s.copy()
# d2=d.copy()
# t2=t[:]
# t2=tuple(t1)
#
#
# # -------------------------------------------------
# # LENGTH
# # -------------------------------------------------
#
# len(l)
# len(t)
# len(s)
# len(d)
#
#
# # -------------------------------------------------
# # ACCESSING
# # -------------------------------------------------
#
# # LIST
# l[0]
#
# # TUPLE
# t[0]
#
# # SET
# # No indexing
#
# # DICTIONARY
# d['name']
#
#
# # -------------------------------------------------
# # STRING CONVERSIONS
# # -------------------------------------------------
#
# list('python')
#
# ''.join(['p','y','t','h','o','n'])
#
#
# # -------------------------------------------------
# # SET OPERATIONS
# # -------------------------------------------------
#
# a={1,2,3}
# b={3,4,5}
#
# a.union(b)
# a.intersection(b)
# a.difference(b)
# a.symmetric_difference(b)
#
# # Operators
#
# a | b       {1,2,3,4,5} Combines all unique elements.
# a & b       {3} Common elements only.
# a - b       {1,2} Elements present in a but not in b.
# a ^ b       {1,2,4,5} Elements not common in both sets.
#
#
# # -------------------------------------------------
# # DICTIONARY METHODS
# # -------------------------------------------------
#
# d.keys()
# d.values()
# d.items()
#
# d.get('name')
#
# d.setdefault('age',21)
#
#
# # -------------------------------------------------
# # COMMONLY CONFUSED METHODS
# # -------------------------------------------------
#
# # LIST
#
# append()      # add one
# extend()      # add many
#
#
# # SET
#
# add()         # add one
# update()      # add many
#
#
# # DICTIONARY
#
# get()         # safe access
# update()      # add/update pairs
#
#
# # -------------------------------------------------
# # IMPORTANT NOTES
# # -------------------------------------------------
#
# # {} creates dictionary NOT set
#
# # Empty set
# set()
#
# # Strings, lists, tuples are ordered
#
# # Sets are unordered
#
# # Tuples are immutable
#
# # Sets remove duplicates automatically
#
# # Dictionary stores key-value pairs

# %% [markdown]
# 1. Write a program to print the sum of elements in a List.

# %%
l=[10,2,22,4,5,22]
print(sum(l))
# Out:
# 65

# %% [markdown]
# 2. Write a program to get the Largest Number in the List.

# %%
l=[10,2,22,4,5,22]
print(max(l))
# Out:
# 22

# %% [markdown]
# 3. Remove Common Elements from two Lists.

# %%
l1=[10,2,22,4,5,22]
l2=[10,33,4,12,22,5]
for i in l2:
    if i in l1:
        l1.remove(i)
        l2.remove(i)
print(l1)
print(l2)
# Out:
# [2, 5, 22]
# [33, 12, 5]

# %%
l1 = [10,2,22,4,5,22]

l2 = [10,33,4,12,22,5]


result = []


for i in l1:

    if i not in l2:

        result.append(i)


for i in l2:

    if i not in l1:

        result.append(i)


print("After Removing Common Elements:", result)
# Out:
# After Removing Common Elements: [2, 33, 12]

# %% [markdown]
# 4. Write a Python program to find the second-smallest number in a List.

# %%
l1=[10,2,22,4,5,22]
least_num=min(l1)
l1.remove(least_num)
print(min(l1))
# Out:
# 4

# %%
l1=[10,2,22,4,5,22]
l1.sort()
print(l1[1])
# Out:
# 4

# %% [markdown]
# 5. Write a Python program to find elements in a given set that are not in another
# set.

# %%
s1={1,33,4,53,44}
s2={3,44,5,2,41,53}
for i in s1:
    if i not in s2:
        print(i)
    else:
        continue
# Out:
# 1
# 33
# 4

# %%
s1={1,33,4,53,44}
s2={3,44,5,2,41,53}
result=s1-s2
print(result)
# Out:
# {1, 4, 33}

# %% [markdown]
# 6. Given two sets of numbers, write a Python program to find the missing
# numbers in the second set as compared to the first and vice versa.

# %%
s1={1,33,4,53,44}
s2={3,44,5,2,41,53}
missing_in_s2=s1-s2
print(missing_in_s2)
missing_in_s1=s2-s1
print(missing_in_s1)
# Out:
# {1, 4, 33}
# {41, 2, 3, 5}

# %% [markdown]
# 7. Write a Python program that finds all pairs of elements in a list whose sum is
# equal to a given value.

# %%
l=[1,2,3,4,5,6,7,8,9]
element=int(input('enter a value:'))
for i in range(len(l)):
    for j in range(i + 1, len(l)):
        if l[i] + l[j] == element:
            print((l[i], l[j]))
            done=True
if done==False:
    print('no pair')
# Out:
# (1, 3)

# %% [markdown]
# 8. Write a Python program to find the two numbers whose product is maximum
# among all the pairs in a given list of numbers and use the Python set.

# %%
s = {2, 4, 7, 1, 9}
l = list(s)
l.sort()
print("Maximum Product", (l[-1], l[-2]))
print("Product:", l[-1] * l[-2])
# Out:
# Maximum Product (9, 7)
# Product: 63

# %% [markdown]
# 9. Write a Python program to find the maximum and minimum values in a set.

# %%
s = {12, 45, 7, 89, 23}
print("Maximum:", max(s))
print("Minimum:", min(s))
# Out:
# Maximum: 89
# Minimum: 7

# %% [markdown]
# 10. Write a Python program to remove an item from a set if it is present in the
# set.

# %%
s = {10, 20, 30, 40}
item = int(input("Enter Item to Remove:"))
if item in s:
    s.remove(item)
    print("Updated Set:",s)
else:
    print("Item Not Present")
# Out:
# Updated Set: {40, 10, 30}

# %% [markdown]
# 11. Write a Python program to create a tuple with different data types.

# %%
t = (10, 3.5, "Python", True)
print(t)
# Out:
# (10, 3.5, 'Python', True)

# %% [markdown]
# 12. Write a Python program to unpack a tuple into several variables.

# %%
t = (10, 20, 30)
a, b, c = t
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %% [markdown]
# 13. Write a Python program to find repeated items in a tuple.

# %%
t = (1, 2, 3, 2, 4, 5, 1)
repeated = set()
for i in t:
    if t.count(i) > 1:
        repeated.add(i)
print("Repeated Items:", repeated)
# Out:
# Repeated Items: {1, 2}

# %% [markdown]
# 14. Write a Python program to reverse a tuple.

# %%
t = (10, 20, 30, 40)
reversed_tuple = t[::-1]
print(reversed_tuple)
# Out:
# (40, 30, 20, 10)

# %%
t=(10,20,30,40)

reverse=tuple(reversed(t))

print(reverse)
# Out:
# (40, 30, 20, 10)

# %% [markdown]
# 15. Write a Python program to replace the last value of the tuples in a list
# [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
# Expected Output: [(10, 20, 100), (40, 50, 100), (70, 80, 100)].

# %%
l=[(10, 20, 40), (40, 50, 60), (70, 80, 90)]
result=[] 
for i in l:
    new_tuple=i[:-1]+(100,)
    result.append(new_tuple)
print(result)
# Out:
# [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %% [markdown]
# 16. Write a Python program to convert a given tuple of positive integers into an
# integer,
#  Original tuple: (1, 2, 3)
#  Expected output: 123

# %%
t=(1,2,3)
output=int(''.join(map(str,t)))
print(output)
# Out:
# 123

# %% [markdown]
# 17. Write a Python program to compute the sum of all the elements of each tuple
# stored inside a list of tuples,
#  Original list of tuples: [(1, 2), (2, 3), (3, 4)]
#  Sum of all the elements of each tuple [3, 5, 7]

# %%
l = [(1, 2), (2, 3), (3, 4)]
result = []
for i in l:
    result.append(sum(i))
print(result)
# Out:
# [3, 5, 7]

# %%
l = [(1, 2), (2, 3), (3, 4)]
for i in range(len(l)):
    print(sum(l[i]),end=' ')
# Out:
# 3 5 7

# %% [markdown]
# 18. Write a Python script to print a dictionary where the keys are numbers
# between 1 and 10 (both included) and the values are the square of the keys.
# Sample Dictionary {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10:
# 100}.

# %%
d = {}
for i in range(1, 11):
    d[i] = i ** 2
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %% [markdown]
# 19. Write a Python program to combine two dictionary by adding values for,
#  common keys.d1 = {'a': 100, 'b': 200, 'c':300} d2 = {'a': 300, 'b': 200, 'd':400}
#  Sample output: Counter ({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
d1 = {'a': 100, 'b': 200, 'c': 300}
d2 = {'a': 300, 'b': 200, 'd': 400}
result = {}
for key in d1:
    result[key]= d1[key]
for key in d2:
    if key in result:
        result[key]+=d2[key]
    else:
        result[key]=d2[key]
print(result)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %% [markdown]
# 20. Write a Python program to convert more than one list to a nested dictionary,
#  Original strings: ['S001', 'S002', 'S003', 'S004']
# ['Adina Park', 'Leyton Marsh', 'Duncan Boyle', 'Saim Richards'] [85, 98, 89,
# 92]
#  Nested dictionary: [{'S001': {'Adina Park': 85}}, {'S002': {'Leyton Marsh':
# 98}}, {'S003': {'Duncan Boyle': 89}}, {'S004': {'Saim Richards': 92}}]

# %%
roll = ['S001', 'S002', 'S003', 'S004']
names = ['Adina Park', 'Leyton Marsh', 'Duncan Boyle', 'Saim Richards']
marks = [85, 98, 89, 92]
result=[]
for i in range(len(roll)):
    d={roll[i]:{names[i]:marks[i]}}
    result.append(d)
print(result)
# Out:
# [{'S001': {'Adina Park': 85}}, {'S002': {'Leyton Marsh': 98}}, {'S003': {'Duncan Boyle': 89}}, {'S004': {'Saim Richards': 92}}]

# %% [markdown]
# 21. Write a Python program to convert a dictionary into a list of lists,
#  Original Dictionary: {1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}
#  Convert the said dictionary into a list of lists: [[1, 'red'], [2, 'green'], [3,
# 'black'], [4, 'white'], [5, 'black']]

# %%
d={1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}
result=[]
for k,v in d.items():
    result.append([k,v])
print(result)
# Out:
# [[1, 'red'], [2, 'green'], [3, 'black'], [4, 'white'], [5, 'black']]

# %% [markdown]
# 22. Write a Python program to get the key, value and item in a dictionary.

# %%
d={1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}
print("Keys:")
for key in d.keys():
    print(key)
print("Values:")
for value in d.values():
    print(value)
print("Items:")
for item in d.items():
    print(item)
# Out:
# Keys:
# 1
# 2
# 3
# 4
# 5
# Values:
# red
# green
# black
# white
# black
# Items:
# (1, 'red')
# (2, 'green')
# (3, 'black')
# (4, 'white')
# (5, 'black')

# %%
d={1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}
print(d.keys())
print(d.values())
print(d.items())
# Out:
# dict_keys([1, 2, 3, 4, 5])
# dict_values(['red', 'green', 'black', 'white', 'black'])
# dict_items([(1, 'red'), (2, 'green'), (3, 'black'), (4, 'white'), (5, 'black')])

# %% [markdown]
# 23. Write a Python program to get the maximum and minimum values of a
# dictionary.

# %%
d={1: 23, 2: 333, 3: 23, 4: 32323, 5: 3232}
print("Maximum Value:", max(d.values()))
print("Minimum Value:", min(d.values()))
# Out:
# Maximum Value: 32323
# Minimum Value: 23
